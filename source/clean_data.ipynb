# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('supermarket_data.csv')

# %%
df
# Out:
#        Unnamed: 0           Организация   ВремяЧека  НомерЧека  НомерКассы  \
# 0               0  Супермаркет "РосМаг"  2024-01-01     102935           4
# 1               1  Супермаркет "РосМаг"  2024-01-01     102935           4
# 2               2  Супермаркет "РосМаг"  2024-01-01     109982           3
# 3               3  Супермаркет "РосМаг"  2024-01-01     109982           3
# 4               4  Супермаркет "РосМаг"  2024-01-01     106511           4
# ...           ...                   ...         ...        ...         ...
# 29786       29786  Супермаркет "РосМаг"  2024-12-31     100269           5
# 29787       29787  Супермаркет "РосМаг"  2024-12-31     100269           5
# 29788       29788  Супермаркет "РосМаг"  2024-12-31     101595           9
# 29789       29789  Супермаркет "РосМаг"  2024-12-31     101595           9
# 29790       29790  Супермаркет "РосМаг"  2024-12-31     101595           9
#
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0      НомерЧека    НомерКассы  НомерАртикула    Количество  \
# count  29791.000000   29791.000000  29791.000000   29791.000000  29791.000000
# mean   14895.000000  104988.953409      5.516196    2010.303414      2.100366
# std     8600.065271    2881.843055      2.864853       5.841077      2.112193
# min        0.000000  100001.000000      1.000000    2001.000000      1.000000
# 25%     7447.500000  102491.000000      3.000000    2005.000000      1.000000
# 50%    14895.000000  104968.000000      6.000000    2010.000000      1.000000
# 75%    22342.500000  107489.000000      8.000000    2015.000000      2.000000
# max    29790.000000  110000.000000     10.000000    2020.000000     23.000000
#
#         Сумма (руб)    Скидка (%)
# count  29791.000000  29791.000000
# mean     173.966837      3.758014
# std      179.117143      6.502889
# min       11.930000      0.000000
# 25%       65.690000      0.000000
# 50%      118.110000      0.000000
# ...

# %%
for column in df.columns:
    print('Column:', column)
    print('Количество', df[column].nunique()),
    print('---' * 10)
# Out:
# Column: Unnamed: 0
# Количество 29791
# ------------------------------
# Column: Организация
# Количество 1
# ------------------------------
# Column: ВремяЧека
# Количество 366
# ------------------------------
# Column: НомерЧека
# Количество 10000
# ------------------------------
# Column: НомерКассы
# Количество 10
# ------------------------------
# Column: НомерТранзакции
# Количество 10000
# ------------------------------
# Column: Кассир
# Количество 50
# ------------------------------
# Column: НомерАртикула
# Количество 20
# ------------------------------
# Column: Товар
# Количество 20
# ------------------------------
# Column: Количество
# Количество 22
# ------------------------------
# Column: Сумма (руб)
# Количество 18939
# ------------------------------
# Column: Скидка (%)
# Количество 5
# ------------------------------

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Организация        0
# ВремяЧека          0
# НомерЧека          0
# НомерКассы         0
# НомерТранзакции    0
# Кассир             0
# НомерАртикула      0
# Товар              0
# Количество         0
# Сумма (руб)        0
# Скидка (%)         0
# dtype: int64

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29791 entries, 0 to 29790
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Организация      29791 non-null  object
#  1   ВремяЧека        29791 non-null  object
#  2   НомерЧека        29791 non-null  int64
#  3   НомерКассы       29791 non-null  int64
#  4   НомерТранзакции  29791 non-null  object
#  5   Кассир           29791 non-null  object
#  6   НомерАртикула    29791 non-null  int64
#  7   Товар            29791 non-null  object
#  8   Количество       29791 non-null  int64
#  9   Сумма (руб)      29791 non-null  float64
#  10  Скидка (%)       29791 non-null  int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 2.5+ MB

# %%
df['ВремяЧека'] = pd.to_datetime(df['ВремяЧека'])
df['НомерАртикула'] = df['НомерАртикула'].apply(lambda x: f"{x:05}")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29791 entries, 0 to 29790
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Организация      29791 non-null  object
#  1   ВремяЧека        29791 non-null  datetime64[ns]
#  2   НомерЧека        29791 non-null  int64
#  3   НомерКассы       29791 non-null  int64
#  4   НомерТранзакции  29791 non-null  object
#  5   Кассир           29791 non-null  object
#  6   НомерАртикула    29791 non-null  object
#  7   Товар            29791 non-null  object
#  8   Количество       29791 non-null  int64
#  9   Сумма (руб)      29791 non-null  float64
#  10  Скидка (%)       29791 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 2.5+ MB

# %%
df = df.rename(columns={'ВремяЧека': 'ДатаЧека'})

# %%
duplicates = df.duplicated()
duplicates.sum()
# Out:
# 0

# %%
df
# Out:
#                 Организация   ДатаЧека  НомерЧека  НомерКассы НомерТранзакции  \
# 0      Супермаркет "РосМаг" 2024-01-01     102935           4         T002935
# 1      Супермаркет "РосМаг" 2024-01-01     102935           4         T002935
# 2      Супермаркет "РосМаг" 2024-01-01     109982           3         T009982
# 3      Супермаркет "РосМаг" 2024-01-01     109982           3         T009982
# 4      Супермаркет "РосМаг" 2024-01-01     106511           4         T006511
# ...                     ...        ...        ...         ...             ...
# 29786  Супермаркет "РосМаг" 2024-12-31     100269           5         T000269
# 29787  Супермаркет "РосМаг" 2024-12-31     100269           5         T000269
# 29788  Супермаркет "РосМаг" 2024-12-31     101595           9         T001595
# 29789  Супермаркет "РосМаг" 2024-12-31     101595           9         T001595
# 29790  Супермаркет "РосМаг" 2024-12-31     101595           9         T001595
#
# ...

# %%
df.to_csv('supermarket_data_cleaned.csv', index=False)

# %% [markdown]
# ---
